# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import load_img
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os

# %%
filenames = os.listdir("newimages")
categories = []
for filename in filenames:
    category = filename[:4]
    if category == 'bird':
        categories.append(0)
    else:
        categories.append(1)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

df = df.sample(frac=1)

# %%
df.head()
# Out:
#               filename  category
# 862        bird670.jpg         0
# 1510  squirrel2241.jpg         1
# 106       bird1417.jpg         0
# 2720   squirrel829.jpg         1
# 832        bird616.jpg         0

# %%
df.tail()
# Out:
#               filename  category
# 467        bird302.jpg         0
# 1179  squirrel1556.jpg         1
# 2773   squirrel939.jpg         1
# 2674    squirrel69.jpg         1
# 126       bird1476.jpg         0

# %%
df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
sample = random.choice(filenames)
image = load_img("newimages/"+sample)
plt.imshow(image)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  batch_normalization (BatchN  (None, 126, 126, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  dropout (Dropout)           (None, 63, 63, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 61, 61, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 128)       0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 12,942,786
# Trainable params: 12,941,314
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

earlyStopping = EarlyStopping(monitor='val_loss', patience=10, verbose=0, mode='min')
mcp_save = ModelCheckpoint('trained models/model2.hdf5', save_best_only=True, monitor='val_loss', mode='min')
reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, epsilon=1e-4, mode='min')

callbacks = [earlyStopping, mcp_save, reduce_lr_loss]
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
df["category"] = df["category"].replace({0: 'bird', 1: 'squirrel'})

# %%
train_df, validate_df = train_test_split(df, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
validate_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=15

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "newimages", 
    x_col='filename',
    y_col='category',
    target_size=(128,128),
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 2247 validated image filenames belonging to 2 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "newimages", 
    x_col='filename',
    y_col='category',
    target_size=(128,128),
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 562 validated image filenames belonging to 2 classes.

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "newimages", 
    x_col='filename',
    y_col='category',
    target_size=(128,128),
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
history = model.fit(
    train_generator, 
    epochs=50,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 149/149 [==============================] - 59s 386ms/step - loss: 1.0543 - accuracy: 0.6214 - val_loss: 1.9540 - val_accuracy: 0.3550 - lr: 0.0010
# Epoch 2/50
# 149/149 [==============================] - 46s 305ms/step - loss: 0.7488 - accuracy: 0.6900 - val_loss: 0.8022 - val_accuracy: 0.6018 - lr: 0.0010
# Epoch 3/50
# 149/149 [==============================] - 45s 302ms/step - loss: 0.6386 - accuracy: 0.7200 - val_loss: 0.7645 - val_accuracy: 0.5856 - lr: 0.0010
# Epoch 4/50
# 149/149 [==============================] - 46s 309ms/step - loss: 0.5892 - accuracy: 0.7222 - val_loss: 0.5534 - val_accuracy: 0.7477 - lr: 0.0010
# Epoch 5/50
# 149/149 [==============================] - 47s 313ms/step - loss: 0.5353 - accuracy: 0.7531 - val_loss: 0.5702 - val_accuracy: 0.7838 - lr: 0.0010
# Epoch 6/50
# 149/149 [==============================] - 45s 305ms/step - loss: 0.5092 - accuracy: 0.7706 - val_loss: 0.5958 - val_accuracy: 0.7369 - lr: 0.0010
# Epoch 7/50
# 149/149 [==============================] - 46s 306ms/step - loss: 0.4849 - accuracy: 0.7769 - val_loss: 0.5651 - val_accuracy: 0.7910 - lr: 0.0010
# Epoch 8/50
# 149/149 [==============================] - 46s 309ms/step - loss: 0.4817 - accuracy: 0.7805 - val_loss: 2.1225 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 9/50
# 149/149 [==============================] - 45s 305ms/step - loss: 0.4709 - accuracy: 0.7979 - val_loss: 0.8009 - val_accuracy: 0.7369 - lr: 0.0010
# Epoch 10/50
# 149/149 [==============================] - 45s 299ms/step - loss: 0.4661 - accuracy: 0.7832 - val_loss: 0.9531 - val_accuracy: 0.6973 - lr: 0.0010
# Epoch 11/50
# 149/149 [==============================] - ETA: 0s - loss: 0.4251 - accuracy: 0.8082
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 149/149 [==============================] - 44s 298ms/step - loss: 0.4251 - accuracy: 0.8082 - val_loss: 0.6245 - val_accuracy: 0.6937 - lr: 0.0010
# Epoch 12/50
# 149/149 [==============================] - 45s 303ms/step - loss: 0.3844 - accuracy: 0.8289 - val_loss: 0.3853 - val_accuracy: 0.8324 - lr: 1.0000e-04
# Epoch 13/50
# 149/149 [==============================] - 45s 300ms/step - loss: 0.3823 - accuracy: 0.8347 - val_loss: 0.3967 - val_accuracy: 0.8306 - lr: 1.0000e-04
# Epoch 14/50
# 149/149 [==============================] - 45s 299ms/step - loss: 0.3616 - accuracy: 0.8396 - val_loss: 0.3573 - val_accuracy: 0.8486 - lr: 1.0000e-04
# Epoch 15/50
# 149/149 [==============================] - 45s 302ms/step - loss: 0.3498 - accuracy: 0.8544 - val_loss: 0.4057 - val_accuracy: 0.8252 - lr: 1.0000e-04
# Epoch 16/50
# 149/149 [==============================] - 46s 310ms/step - loss: 0.3440 - accuracy: 0.8432 - val_loss: 0.3698 - val_accuracy: 0.8631 - lr: 1.0000e-04
# Epoch 17/50
# 149/149 [==============================] - 46s 311ms/step - loss: 0.3508 - accuracy: 0.8562 - val_loss: 0.3565 - val_accuracy: 0.8703 - lr: 1.0000e-04
# Epoch 18/50
# 149/149 [==============================] - 46s 311ms/step - loss: 0.3405 - accuracy: 0.8490 - val_loss: 0.3634 - val_accuracy: 0.8559 - lr: 1.0000e-04
# Epoch 19/50
# 149/149 [==============================] - 46s 308ms/step - loss: 0.3448 - accuracy: 0.8553 - val_loss: 0.3758 - val_accuracy: 0.8631 - lr: 1.0000e-04
# Epoch 20/50
# 149/149 [==============================] - 46s 307ms/step - loss: 0.3275 - accuracy: 0.8616 - val_loss: 0.4589 - val_accuracy: 0.8541 - lr: 1.0000e-04
# Epoch 21/50
# 149/149 [==============================] - 45s 304ms/step - loss: 0.3272 - accuracy: 0.8593 - val_loss: 0.3656 - val_accuracy: 0.8703 - lr: 1.0000e-04
# Epoch 22/50
# 149/149 [==============================] - 45s 301ms/step - loss: 0.3440 - accuracy: 0.8530 - val_loss: 0.3788 - val_accuracy: 0.8667 - lr: 1.0000e-04
# Epoch 23/50
# 149/149 [==============================] - 45s 300ms/step - loss: 0.3401 - accuracy: 0.8499 - val_loss: 0.5351 - val_accuracy: 0.8270 - lr: 1.0000e-04
# Epoch 24/50
# 149/149 [==============================] - ETA: 0s - loss: 0.3260 - accuracy: 0.8571
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 149/149 [==============================] - 45s 301ms/step - loss: 0.3260 - accuracy: 0.8571 - val_loss: 0.3677 - val_accuracy: 0.8721 - lr: 1.0000e-04
# Epoch 25/50
# 149/149 [==============================] - 45s 302ms/step - loss: 0.3350 - accuracy: 0.8566 - val_loss: 0.3895 - val_accuracy: 0.8685 - lr: 1.0000e-05
# Epoch 26/50
# 149/149 [==============================] - 45s 302ms/step - loss: 0.3291 - accuracy: 0.8530 - val_loss: 0.4044 - val_accuracy: 0.8595 - lr: 1.0000e-05
# Epoch 27/50
# 149/149 [==============================] - 45s 299ms/step - loss: 0.3222 - accuracy: 0.8656 - val_loss: 0.4052 - val_accuracy: 0.8631 - lr: 1.0000e-05

# %%
model.save_weights('../model.h6')

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, 50, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, 50, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %%
test_filenames = os.listdir("newimages")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "newimages", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=(128,128),
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 2809 validated image filenames.

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))
# Out:
# C:\Users\ctoconnor\AppData\Local\Temp\ipykernel_14168\3090721588.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))

# %%
test_df['category'] = np.argmax(predict, axis=-1)

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)

# %%
test_df['category'] = test_df['category'].replace({ 'bird': 0, 'squirrel': 1 })

# %%
test_df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot: >

# %%
sample_test = test_df.head(51)
sample_test.head()
plt.figure(figsize=(12, 30))
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    img = load_img("newimages/"+filename, target_size=(128,128))
    plt.subplot(17, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(category) + ')' )
plt.tight_layout()
plt.show()
